# %%
class Node:
    def __init__(self, node_id):
        self.node_id = node_id
        self.leader = None

    def __str__(self):
        return f"Node {self.node_id}"

    def start_election(self, nodes):
        print(f"{self} initiates an election.")
        higher_nodes = [node for node in nodes if node.node_id > self.node_id]

        # Send election messages to higher nodes
        for higher_node in higher_nodes:
            higher_node.receive_election(self)

    def receive_election(self, initiating_node):
        """Receive an election message and respond accordingly."""
        print(
            f"{self} receives an election message from {initiating_node}.")
        if self.leader is None or self.node_id > self.leader.node_id:
            print(
                f"{self} sends an OK message to {initiating_node}.")
            initiating_node.receive_ok(self)
        else:
            print(
                f"{self} ignores the election message from {initiating_node}.")

    def receive_ok(self, responding_node):
        """Receive an OK message and acknowledge the leader."""
        print(
            f"{self} receives an OK message from {responding_node}.")
        self.leader = responding_node
        print(
            f"{self} acknowledges {responding_node} as the leader.")

if __name__ == "__main__":
    # Create nodes with unique IDs
    nodes = [Node(1), Node(2), Node(3), Node(4), Node(5), Node(6), Node(7)]

    # Simulate leader election
    for node in nodes:
        node.start_election(nodes)

    # Find the elected leader
    elected_leader = max(nodes, key=lambda node: node.node_id)

    print(f"\n{elected_leader} is elected as the leader.")
# Out:
# Node 1 initiates an election.
# Node 2 receives an election message from Node 1.
# Node 2 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 2.
# Node 1 acknowledges Node 2 as the leader.
# Node 3 receives an election message from Node 1.
# Node 3 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 3.
# Node 1 acknowledges Node 3 as the leader.
# Node 4 receives an election message from Node 1.
# Node 4 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 4.
# Node 1 acknowledges Node 4 as the leader.
# Node 5 receives an election message from Node 1.
# Node 5 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 5.
# Node 1 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 1.
# Node 6 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 6.
# Node 1 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 1.
# Node 7 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 7.
# Node 1 acknowledges Node 7 as the leader.
# Node 2 initiates an election.
# Node 3 receives an election message from Node 2.
# Node 3 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 3.
# Node 2 acknowledges Node 3 as the leader.
# Node 4 receives an election message from Node 2.
# Node 4 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 4.
# Node 2 acknowledges Node 4 as the leader.
# Node 5 receives an election message from Node 2.
# Node 5 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 5.
# Node 2 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 2.
# Node 6 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 6.
# Node 2 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 2.
# Node 7 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 7.
# Node 2 acknowledges Node 7 as the leader.
# Node 3 initiates an election.
# Node 4 receives an election message from Node 3.
# Node 4 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 4.
# Node 3 acknowledges Node 4 as the leader.
# Node 5 receives an election message from Node 3.
# Node 5 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 5.
# Node 3 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 3.
# Node 6 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 6.
# Node 3 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 3.
# Node 7 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 7.
# Node 3 acknowledges Node 7 as the leader.
# Node 4 initiates an election.
# Node 5 receives an election message from Node 4.
# Node 5 sends an OK message to Node 4.
# Node 4 receives an OK message from Node 5.
# Node 4 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 4.
# Node 6 sends an OK message to Node 4.
# Node 4 receives an OK message from Node 6.
# Node 4 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 4.
# Node 7 sends an OK message to Node 4.
# Node 4 receives an OK message from Node 7.
# Node 4 acknowledges Node 7 as the leader.
# Node 5 initiates an election.
# Node 6 receives an election message from Node 5.
# Node 6 sends an OK message to Node 5.
# Node 5 receives an OK message from Node 6.
# Node 5 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 5.
# Node 7 sends an OK message to Node 5.
# Node 5 receives an OK message from Node 7.
# Node 5 acknowledges Node 7 as the leader.
# Node 6 initiates an election.
# Node 7 receives an election message from Node 6.
# Node 7 sends an OK message to Node 6.
# Node 6 receives an OK message from Node 7.
# Node 6 acknowledges Node 7 as the leader.
# Node 7 initiates an election.
#
# Node 7 is elected as the leader.

# %%
class Node:
    def __init__(self, node_id):
        self.node_id = node_id
        self.leader = None

    def __str__(self):
        return f"Node {self.node_id}"

    def start_election(self, nodes):
        """Initiate an election process."""
        print(f"{self} initiates an election.")
        higher_nodes = [node for node in nodes if node.node_id > self.node_id]

        # Send election messages to higher nodes
        for higher_node in higher_nodes:
            higher_node.receive_election(self)

    def receive_election(self, initiating_node):
        """Receive an election message and respond accordingly."""
        print(
            f"{self} receives an election message from {initiating_node}.")
        if self.leader is None or self.node_id > self.leader.node_id:
            print(
                f"{self} sends an OK message to {initiating_node}.")
            initiating_node.receive_ok(self)
        else:
            print(
                f"{self} ignores the election message from {initiating_node}.")

    def receive_ok(self, responding_node):
        """Receive an OK message and acknowledge the leader."""
        print(
            f"{self} receives an OK message from {responding_node}.")
        self.leader = responding_node
        print(
            f"{self} acknowledges {responding_node} as the leader.")

if __name__ == "__main__":
    # Create nodes with unique IDs
    nodes = [Node(1), Node(2), Node(3), Node(4), Node(5), Node(6), Node(7)]

    # Simulate leader election
    for node in nodes:
        node.start_election(nodes)

    # Find the elected leader
    elected_leader = max(nodes, key=lambda node: node.node_id)

    print(f"\n{elected_leader} is elected as the leader.")
# Out:
# Node 1 initiates an election.
# Node 2 receives an election message from Node 1.
# Node 2 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 2.
# Node 1 acknowledges Node 2 as the leader.
# Node 3 receives an election message from Node 1.
# Node 3 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 3.
# Node 1 acknowledges Node 3 as the leader.
# Node 4 receives an election message from Node 1.
# Node 4 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 4.
# Node 1 acknowledges Node 4 as the leader.
# Node 5 receives an election message from Node 1.
# Node 5 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 5.
# Node 1 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 1.
# Node 6 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 6.
# Node 1 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 1.
# Node 7 sends an OK message to Node 1.
# Node 1 receives an OK message from Node 7.
# Node 1 acknowledges Node 7 as the leader.
# Node 2 initiates an election.
# Node 3 receives an election message from Node 2.
# Node 3 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 3.
# Node 2 acknowledges Node 3 as the leader.
# Node 4 receives an election message from Node 2.
# Node 4 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 4.
# Node 2 acknowledges Node 4 as the leader.
# Node 5 receives an election message from Node 2.
# Node 5 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 5.
# Node 2 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 2.
# Node 6 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 6.
# Node 2 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 2.
# Node 7 sends an OK message to Node 2.
# Node 2 receives an OK message from Node 7.
# Node 2 acknowledges Node 7 as the leader.
# Node 3 initiates an election.
# Node 4 receives an election message from Node 3.
# Node 4 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 4.
# Node 3 acknowledges Node 4 as the leader.
# Node 5 receives an election message from Node 3.
# Node 5 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 5.
# Node 3 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 3.
# Node 6 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 6.
# Node 3 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 3.
# Node 7 sends an OK message to Node 3.
# Node 3 receives an OK message from Node 7.
# Node 3 acknowledges Node 7 as the leader.
# Node 4 initiates an election.
# Node 5 receives an election message from Node 4.
# Node 5 sends an OK message to Node 4.
# Node 4 receives an OK message from Node 5.
# Node 4 acknowledges Node 5 as the leader.
# Node 6 receives an election message from Node 4.
# Node 6 sends an OK message to Node 4.
# Node 4 receives an OK message from Node 6.
# Node 4 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 4.
# Node 7 sends an OK message to Node 4.
# Node 4 receives an OK message from Node 7.
# Node 4 acknowledges Node 7 as the leader.
# Node 5 initiates an election.
# Node 6 receives an election message from Node 5.
# Node 6 sends an OK message to Node 5.
# Node 5 receives an OK message from Node 6.
# Node 5 acknowledges Node 6 as the leader.
# Node 7 receives an election message from Node 5.
# Node 7 sends an OK message to Node 5.
# Node 5 receives an OK message from Node 7.
# Node 5 acknowledges Node 7 as the leader.
# Node 6 initiates an election.
# Node 7 receives an election message from Node 6.
# Node 7 sends an OK message to Node 6.
# Node 6 receives an OK message from Node 7.
# Node 6 acknowledges Node 7 as the leader.
# Node 7 initiates an election.
#
# Node 7 is elected as the leader.
